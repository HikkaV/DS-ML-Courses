# %% [markdown]
# <pre style='font-size : 25px; text-align : center '><b>ASSIGNMENT 3</b></pre>
# <pre style='font-size : 20px;'><b>INSPECTING AND SOLVING THE PROBLEM OF OVERFITTING</b></pre>
# <pre style='font-size : 15px'>This time we will try to solve the problem of overfitting which occurred during the training of our classifiers on boston housing data. In order to solve it we will use an l1 and l2 regularization. Moreover, we will scale our features in order to squash them into the [0,1] range. We then will compare the obtained results to the previous ones.</pre>
#
# <i>Note : that's a test version of a notebook</i>

# %% [markdown]
# <pre style='font-size : 20px'><b>PART 1</b></pre>
# <pre style='font-size : 18px'><b>Linear regression with regularization</b></pre>
# <pre style='font-size : 15px;'>Firstly let's import necessary packages. </pre>

# %%
#Ridge - regression with l2 regularization, Lasso - regression with l1 regularization  
from sklearn.linear_model import  Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <pre style='font-size : 15px'>Now it's time to load our dataset</pre>

# %%
def load_boston_df():
    from sklearn import datasets
    boston_data = datasets.load_boston()
    columns_to_use = ['data','target','feature_names']
    boston_data = dict([(i,boston_data[i]) for i in columns_to_use])
    df = pd.DataFrame(columns=boston_data['feature_names'], data=boston_data['data'])
    df['target'] = boston_data['target']
    return df

# %%
df = load_boston_df()

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %% [markdown]
# <pre style='font-size : 15px'>Now let's process our features and split our data</pre>

# %%
train_columns = list(df.columns)
target_column = train_columns.pop(-1)

# %%
train_set, test_set = train_test_split(df,test_size=0.20, random_state=seed)
X_train, y_train, X_test, y_test = train_set[train_columns], train_set[target_column],\
test_set[train_columns], test_set[target_column]

# %%
#Firstly, we created a MinMaxScaler instance and fit it to all the features available in data
scaler = MinMaxScaler().fit(df[train_columns])
#We then used it to transform both train and test features
X_train, X_test = scaler.transform(X_train), scaler.transform(X_test)

# %% [markdown]
# <pre style='font-size :15px'>Firstly let's try out l1 regularization using Lasso regression. One thing we need to specify when using regularization is a value of alpha parameter, the intuition behind which the following : one alpha is large - the bigger regularization effect is and vice versa.</pre>

# %%
#alpha - regularization strength, feel free to play around with this parameter and see the results
alpha = 0.001

# %%
clf = Lasso(alpha=alpha,random_state=seed)

# %%
clf.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=5,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
y_predicted_train = clf.predict(X_train)
print("Mean squared error on train data : {0}".format(mean_squared_error(y_predicted_train,y_train)))
# Out:
# Mean squared error on train data : 22.477970840670434

# %%
y_predicted_test = clf.predict(X_test)
print("Mean squared error on test data : {0}".format(mean_squared_error(y_predicted_test,y_test)))
# Out:
# Mean squared error on test data : 20.81651492653228

# %% [markdown]
# <pre style='font-size :15px'>Trying Lasso regression we see small changes in mse score for both test and train set, let's give l2 regularization a try (Ridge)<pre>

# %%
#alpha - regularization strength, feel free to play around with this parameter and see the results
alpha = 1

# %%
clf = Ridge(alpha=alpha,random_state=seed)

# %%
clf.fit(X_train,y_train)
# Out:
# Ridge(alpha=1, copy_X=True, fit_intercept=True, max_iter=None, normalize=False,
#       random_state=5, solver='auto', tol=0.001)

# %%
y_predicted_train = clf.predict(X_train)
print("Mean squared error on train data : {0}".format(mean_squared_error(y_predicted_train,y_train)))
# Out:
# Mean squared error on train data : 22.85593814100752

# %%
y_predicted_test = clf.predict(X_test)
print("Mean squared error on test data : {0}".format(mean_squared_error(y_predicted_test,y_test)))
# Out:
# Mean squared error on test data : 20.120551230578396

# %% [markdown]
# <pre style='font-size : 15px'>We also see no huge changes using regulariztion on linear regression, let's try it with polynomial regression</pre>

# %% [markdown]
# <pre style='font-size : 20px'><b>PART 2</b></pre>
# <pre style='font-size : 18px'><b>Polynomial regression with regularization</b></pre>

# %%
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# <pre style='font-size : 15px'>As always we will firstly create our polynomial features</pre>

# %%
#C- degree of polynom. Feel free to play around with number and see the perfomance of the model depending on it
C =2

# %%
poly = PolynomialFeatures(C)

# %%
poly_features_train = poly.fit_transform(X_train)
poly_features_test = poly.transform(X_test)

# %% [markdown]
# <pre style='font-size :15px'>We will start with l1 (Lasso) regularization</pre>

# %%
#alpha - regularization strength, feel free to play around with this parameter and see the results
#max_iter - number of iterations of the algorithm,feel free to play around with this parameter and see the results
alpha = 0.001
max_iter = 100000

# %%
clf = Lasso(alpha=alpha,max_iter=max_iter,random_state=seed)

# %%
clf.fit(poly_features_train,y_train)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=100000,
#       normalize=False, positive=False, precompute=False, random_state=5,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
y_predicted_train = clf.predict(poly_features_train)
print("Mean squared error on train data : {0}".format(mean_squared_error(y_predicted_train,y_train)))
# Out:
# Mean squared error on train data : 6.932357489872983

# %%
y_predicted_test = clf.predict(poly_features_test)
print("Mean squared error on test data : {0}".format(mean_squared_error(y_predicted_test,y_test)))
# Out:
# Mean squared error on test data : 8.71303350292541

# %% [markdown]
# <pre style ='font-size:15px'>Finally the regularization for polynomial regresion worked and there is some intuition why it didn't work so well for linear regression. What really regularization does is making our decision boudaries simpler, to ecnourage the generalization to unseen data. And the decision boundary of linear regression is just a line, thus there is no way regularization can make it even simpler. To understand it beter, let's plot our predictions versus real target values on test set using the l1 regularization. (for convinience we will use RM feature as y) </pre>

# %%
import numpy as np

# %%
sns.set()
def plot_boundaries(alpha=0.1,C=2, max_iter=100000):
    clf = Lasso(alpha=alpha,max_iter=max_iter)
    poly = PolynomialFeatures(C)
    poly_features_train = poly.fit_transform(X_train)
    poly_features_test = poly.transform(X_test)
    clf.fit(poly_features_train,y_train)
    y_predicted_test = clf.predict(poly_features_test)
    mae = mean_squared_error(y_predicted_test,y_test)
    plt.figure(figsize=(15,12))
    plt.title('Predictions on test data with alpha of {0} ; test mse score of {1} ; polynomial degree of {2}'.format(alpha,mae, C))
    plt.scatter(y_test,test_set['RM'])
    plt.scatter(y_predicted_test, test_set['RM'],color='g', marker='^')
    plt.ylabel('Number of rooms')
    plt.xlabel('Price')
    plt.legend(['Real value','Predicted value'])

# %%
plot_boundaries(alpha=0.001,C=3)

# %%
plot_boundaries(alpha=1, C=3)

# %%
plot_boundaries(alpha=10, C=3)

# %% [markdown]
# <pre style='font-size :15px'>Now let's try to use l2 regularization (Ridge) and see the results!</pre>

# %%
#C- degree of polynom. Feel free to play around with number and see the perfomance of the model depending on it
C = 3
poly = PolynomialFeatures(C)

# %%
poly_features_train = poly.fit_transform(X_train)
poly_features_test = poly.transform(X_test)

# %%
#alpha - regularization strength, feel free to play around with this parameter and see the results
#max_iter - number of iterations of the algorithm,feel free to play around with this parameter and see the results
alpha = 0.1
max_iter = 1000000

# %%
clf = Ridge(alpha=alpha,max_iter=max_iter,random_state=seed)

# %%
clf.fit(poly_features_train,y_train)
# Out:
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000000,
#       normalize=False, random_state=5, solver='auto', tol=0.001)

# %%
y_predicted_train = clf.predict(poly_features_train)
print("Mean squared error on train data : {0}".format(mean_squared_error(y_predicted_train,y_train)))
# Out:
# Mean squared error on train data : 5.622453570543141

# %%
y_predicted_test = clf.predict(poly_features_test)
print("Mean squared error on test data : {0}".format(mean_squared_error(y_predicted_test,y_test)))
# Out:
# Mean squared error on test data : 7.139789155900653

# %% [markdown]
# <pre style='font-size :15px'>Using Ridge regression with a polynomial degree of 3 we got 7 mse score on test data, thus l2 regularization also worked well. Let's see the comparison  of Lasso and Ridge regression versus real target value. </pre>

# %%
def plot_bestresults_comparison():
    clf = Ridge(alpha=0.1,max_iter=1000000,random_state=seed)
    C = 3
    poly = PolynomialFeatures(C)
    poly_features_train = poly.fit_transform(X_train)
    poly_features_test = poly.transform(X_test)
    clf.fit(poly_features_train,y_train)
    y_predicted_ridge = clf.predict(poly_features_test)
    clf = Lasso(alpha=0.001,max_iter=1000000)
    C = 3
    poly = PolynomialFeatures(C)
    poly_features_train = poly.fit_transform(X_train)
    poly_features_test = poly.transform(X_test)
    clf.fit(poly_features_train,y_train)
    y_predicted_lasso = clf.predict(poly_features_test)
    plt.figure(figsize=(15,12))
    plt.title('Comparison of Lasso and Ridge regression versus real target value')
    plt.scatter(y_test,test_set['RM'])
    plt.scatter(y_predicted_lasso, test_set['RM'],color='g', marker='^')
    plt.scatter(y_predicted_ridge,test_set['RM'],color='r',marker='x')
    plt.ylabel('Number of rooms')
    plt.xlabel('Price')
    plt.legend(['Real valalue','Predicted value with Lasso (l1)','Predicted value with Ridge (l2)'])

# %%
plot_bestresults_comparison()

# %% [markdown]
# <pre style='font-size : 15px'>Finally, we can see the real difference between predicted values and real ones, by printing them side by side. In our case we will use the  prices predicted by polynomial regression with l1 regularization (Lasso), as it showed the best results on test data.</pre>

# %%
def show_dif():
    clf = Ridge(alpha=0.1,max_iter=1000000)
    C = 3
    poly = PolynomialFeatures(C)
    poly_features_train = poly.fit_transform(X_train)
    poly_features_test = poly.transform(X_test)
    clf.fit(poly_features_train,y_train)
    y_predicted_lasso = clf.predict(poly_features_test)
    for i in zip(y_predicted_lasso,y_test.values):
        print('Predicted price : {0}; Real price : {1};'.format(i[0],i[1]))

# %%
show_dif()
# Out:
# Predicted price : 41.841395961126835; Real price : 37.6;
# Predicted price : 28.915159409061918; Real price : 27.9;
# Predicted price : 25.210076701727292; Real price : 22.6;
# Predicted price : 10.63903522838827; Real price : 13.8;
# Predicted price : 35.69578373119587; Real price : 35.2;
# Predicted price : 9.129101334641677; Real price : 10.4;
# Predicted price : 24.393783839348085; Real price : 23.9;
# Predicted price : 27.835498031060244; Real price : 29.0;
# Predicted price : 23.96014312272473; Real price : 22.8;
# Predicted price : 21.11843829090042; Real price : 23.2;
# Predicted price : 34.176253568713776; Real price : 33.2;
# Predicted price : 22.006369556887762; Real price : 19.0;
# Predicted price : 20.408371385930934; Real price : 20.3;
# Predicted price : 34.64613360195699; Real price : 36.1;
# Predicted price : 26.10232941347686; Real price : 24.4;
# Predicted price : 17.909267749349603; Real price : 17.2;
# Predicted price : 12.783283715668523; Real price : 17.9;
# Predicted price : 14.223314604199519; Real price : 19.6;
# Predicted price : 16.718685636384837; Real price : 19.7;
# Predicted price : 21.674638085216635; Real price : 15.0;
# Predicted price : 9.110725531102137; Real price : 8.1;
# Predicted price : 19.8064610780935; Real price : 23.0;
# Predicted price : 44.03659292664237; Real price : 44.8;
# Predicted price : 23.003968299025082; Real price : 23.1;
# Predicted price : 33.02982338402953; Real price : 32.2;
# Predicted price : 9.779678537439754; Real price : 10.8;
# Predicted price : 24.299682884205737; Real price : 23.1;
# Predicted price : 21.206235737840665; Real price : 21.2;
# Predicted price : 23.63533808054678; Real price : 22.2;
# Predicted price : 25.641520527747407; Real price : 24.1;
# Predicted price : 17.005703259133874; Real price : 17.3;
# Predicted price : 10.868333387215236; Real price : 7.0;
# Predicted price : 17.596719213261217; Real price : 12.7;
# Predicted price : 13.462727905316312; Real price : 17.8;
# Predicted price : 26.540706267892; Real price : 26.4;
# Predicted price : 18.809758413710753; Real price : 19.6;
# Predicted price : 26.842862656725668; Real price : 25.1;
# Predicted price : 11.232674688635115; Real price : 8.3;
# Predicted price : 48.319156405510796; Real price : 48.8;
# Predicted price : 35.31545759180488; Real price : 34.9;
# Predicted price : 19.885259981536137; Real price : 13.8;
# Predicted price : 13.300633653487738; Real price : 14.4;
# Predicted price : 28.18822987700259; Real price : 30.1;
# Predicted price : 13.728568976055579; Real price : 12.7;
# Predicted price : 26.40004004310477; Real price : 27.1;
# Predicted price : 28.06654570386274; Real price : 24.8;
# Predicted price : 8.192185909983309; Real price : 7.0;
# Predicted price : 19.184480106371737; Real price : 20.5;
# Predicted price : 19.79782857664585; Real price : 21.5;
# Predicted price : 16.146675308630414; Real price : 14.0;
# Predicted price : 20.67491436401064; Real price : 20.4;
# Predicted price : 21.188186019751143; Real price : 22.2;
# Predicted price : 22.620177214399483; Real price : 21.4;
# Predicted price : 14.61752220622353; Real price : 13.5;
# Predicted price : 15.686994775374156; Real price : 19.4;
# Predicted price : 24.414653693295193; Real price : 24.7;
# Predicted price : 41.670338606697456; Real price : 43.8;
# Predicted price : 13.648420924615412; Real price : 14.1;
# Predicted price : 28.755038613828066; Real price : 28.6;
# Predicted price : 20.78844361313243; Real price : 19.7;
# Predicted price : 19.105956042397477; Real price : 16.8;
# Predicted price : 24.284582591972967; Real price : 23.2;
# Predicted price : 15.280538570253247; Real price : 16.2;
# Predicted price : 36.462385652142345; Real price : 41.3;
# Predicted price : 23.621180339626004; Real price : 22.7;
# Predicted price : 12.674725875312468; Real price : 8.3;
# Predicted price : 17.46162443628186; Real price : 18.4;
# Predicted price : 24.307188668441274; Real price : 24.7;
# Predicted price : 20.421641534240287; Real price : 21.7;
# Predicted price : 23.5197216849809; Real price : 20.6;
# Predicted price : 16.83240321648018; Real price : 16.7;
# Predicted price : 25.1765749769592; Real price : 22.1;
# Predicted price : 18.128604874193428; Real price : 19.4;
# Predicted price : 15.451509246004523; Real price : 27.5;
# Predicted price : 26.85353768183452; Real price : 27.9;
# Predicted price : 30.65365784384261; Real price : 30.1;
# Predicted price : 20.205022574528456; Real price : 17.4;
# Predicted price : 15.79997969391152; Real price : 15.4;
# Predicted price : 34.02507094955587; Real price : 31.0;
# Predicted price : 18.69095482135156; Real price : 14.2;
# Predicted price : 23.26493025468288; Real price : 19.6;
# Predicted price : 49.759951486272854; Real price : 50.0;
# Predicted price : 21.872126888415146; Real price : 21.7;
# Predicted price : 16.283833650840336; Real price : 11.7;
# Predicted price : 19.11195594250374; Real price : 19.4;
# Predicted price : 13.496502599320507; Real price : 13.0;
# Predicted price : 18.14011565376116; Real price : 17.5;
# Predicted price : 10.852880673855672; Real price : 9.7;
# Predicted price : 18.080940093899617; Real price : 20.3;
# Predicted price : 20.567724980701055; Real price : 18.6;
# Predicted price : 43.49958125153117; Real price : 50.0;
# Predicted price : 16.161316610123063; Real price : 19.6;
# Predicted price : 23.02118092219294; Real price : 21.4;
# Predicted price : 15.865461958084687; Real price : 18.4;
# Predicted price : 23.862902292852635; Real price : 22.6;
# Predicted price : 27.287999213509373; Real price : 25.0;
# Predicted price : 14.551740666715672; Real price : 15.6;
# Predicted price : 27.41923499187965; Real price : 26.6;
# Predicted price : 22.844004240189292; Real price : 22.4;
# Predicted price : 12.843861963934566; Real price : 13.1;
# Predicted price : 23.49879080655715; Real price : 23.0;
# Predicted price : 21.988901316103778; Real price : 24.5;

# %% [markdown]
# <pre style='font-size :15px'>In the next lessons we will consider using SVM algorithm for solving this task.</pre>
